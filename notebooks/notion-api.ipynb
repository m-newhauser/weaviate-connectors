# %%
from dotenv import load_dotenv
import os
from notion_client import Client

from pprint import pprint

load_dotenv()

notion_token = os.getenv('NOTION_TOKEN')

# Initialize the Notion client
notion = Client(auth=notion_token)

# %% [markdown]
# Most of the documentation revolves around retrieving database objects. However, when I try to retrieve all the database objects in my person notion, I only get 2 databases and 0 pages.

# %%
# Function to search for databases in the workspace
def get_databases():
    response = notion.search(
        filter={
            "value": "database",
            "property": "object"
        }
    )
    return response

# Get the databases and print them
databases = get_databases()

# Extracting the database IDs
database_ids = [result['id'] for result in databases['results'] if result['object'] == 'database']

# %%
databases
# Out:
# {'object': 'list',
#  'results': [{'object': 'database',
#    'id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#    'cover': None,
#    'icon': {'type': 'emoji', 'emoji': '📑'},
#    'created_time': '2023-02-13T20:40:00.000Z',
#    'created_by': {'object': 'user',
#     'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92'},
#    'last_edited_by': {'object': 'user',
#     'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92'},
#    'last_edited_time': '2024-09-23T13:23:00.000Z',
#    'title': [{'type': 'text',
#      'text': {'content': 'ML Library', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'ML Library',
#      'href': None}],
#    'description': [],
#    'is_inline': False,
#    'properties': {'URL': {'id': 'IlqV',
#      'name': 'URL',
#      'type': 'url',
#      'url': {}},
#     'Tags': {'id': 'lo%3Cz',
#      'name': 'Tags',
#      'type': 'multi_select',
#      'multi_select': {'options': [{'id': 'xG=B',
#         'name': 'organization',
#         'color': 'orange',
#         'description': None},
#        {'id': 'eb5b6539-d1d1-4a2d-8211-7f4050d5f7fb',
#         'name': 'portfolio',
#         'color': 'red',
#         'description': None},
#        {'id': '002ff61b-787d-4c14-a8e2-f30c73f2f677',
#         'name': 'code',
#         'color': 'gray',
#         'description': None},
#        {'id': 'd140b1c5-d3ce-43f9-af55-a302a2cbe31d',
#         'name': 'tutorial',
#         'color': 'blue',
#         'description': None},
#        {'id': 'e8ae4fd1-d010-4ee0-b641-2114a5f0c0ef',
#         'name': 'coding',
#         'color': 'pink',
#         'description': None},
#        {'id': 'f6f26d21-6434-41dc-a92b-8a59b85476d3',
#         'name': 'software engineering',
#         'color': 'brown',
#         'description': None},
#        {'id': '5a50af15-2d86-490b-8cf6-22fadf4e7982',
#         'name': 'learning',
#         'color': 'red',
#         'description': None},
#        {'id': '94a29f0b-95ee-4a22-a8fc-43f37d30ddde',
#         'name': 'pandas',
#         'color': 'green',
#         'description': None},
#        {'id': 'e8e0c835-107a-49bb-8a16-3a7301822cdc',
#         'name': 'transformers',
#         'color': 'yellow',
#         'description': None},
#        {'id': '5331457a-386f-454e-8a5f-a2dd44185df3',
#         'name': 'viz',
#         'color': 'purple',
#         'description': None},
#        {'id': '53fc6407-3a91-4070-be31-5067d85f4bb5',
#         'name': 'MLOps',
#         'color': 'default',
#         'description': None},
#        {'id': 'f740529c-bc2b-4143-8b19-cc8d0fa28809',
#         'name': 'blog',
#         'color': 'default',
#         'description': None},
#        {'id': 'f84fa0b1-c78d-4797-b027-f5cb3c241f88',
#         'name': 'career',
#         'color': 'default',
#         'description': None},
#        {'id': '85f28320-bf3d-44df-a92c-ec3a3cd214c5',
#         'name': 'tools',
#         'color': 'default',
#         'description': None},
#        {'id': '5a1a360f-e246-40e8-a7ce-399366e005ad',
#         'name': 'packages',
#         'color': 'pink',
#         'description': None},
#        {'id': '147a4acc-7510-4b66-8a99-44f59271c1ae',
#         'name': 'course',
#         'color': 'default',
#         'description': None},
#        {'id': '933082e4-7908-4190-8b2a-a79136129ce2',
#         'name': 'statistics',
#         'color': 'default',
#         'description': None},
#        {'id': '75420dd9-1bd4-4dc4-881c-eb9605223c75',
#         'name': 'data cleaning',
#         'color': 'default',
#         'description': None},
#        {'id': 'f4e08240-9e0f-491d-9b83-dfab8a58ff80',
#         'name': 'EDA',
#         'color': 'default',
#         'description': None},
#        {'id': '8426825d-cabe-4f4c-9ebc-1fc79fabcc15',
#         'name': 'cheat sheet',
#         'color': 'default',
#         'description': None},
#        {'id': '91623ecb-7699-46f1-968f-0724eff55ab6',
#         'name': 'interview',
#         'color': 'default',
#         'description': None},
#        {'id': 'cc2c7544-a96f-4cf3-bb6f-6565ff5a0720',
#         'name': 'deep learning',
#         'color': 'default',
#         'description': None},
#        {'id': '860fc9f8-b62c-4a9e-819a-0058cff25e1d',
#         'name': 'model selection',
#         'color': 'default',
#         'description': None},
#        {'id': 'f003ee9b-8a8b-4b5f-8717-b5b015b083bc',
#         'name': 'LLMs',
#         'color': 'default',
#         'description': None},
#        {'id': '91388bec-6859-4c3f-b623-0419aefed0fd',
#         'name': 'RLHF',
#         'color': 'default',
#         'description': None},
#        {'id': 'bc32e6e3-ce3d-4582-ace3-4980c8573414',
#         'name': 'Computer vision',
#         'color': 'default',
#         'description': None},
#        {'id': '925d193a-f7dd-4703-bb6a-d39e11fbf612',
#         'name': 'collaborations',
#         'color': 'default',
#         'description': None},
#        {'id': '279b4958-ca2d-4408-b99f-0dcd6418c6e1',
#         'name': 'funding',
#         'color': 'default',
#         'description': None},
#        {'id': 'e9414ad4-0cfb-4d35-bc6f-f6268ef3f13f',
#         'name': 'strategy',
#         'color': 'default',
#         'description': None},
#        {'id': '12ceffc8-1b1e-49a7-900b-84204575ca9c',
#         'name': 'llm',
#         'color': 'brown',
#         'description': None},
#        {'id': '4a03ebc1-f736-46a1-8095-d55b60925604',
#         'name': 'post sources',
#         'color': 'orange',
#         'description': None},
#        {'id': '7efa6f74-53a4-4324-b8c3-8884c60c28aa',
#         'name': 'annotation',
#         'color': 'purple',
#         'description': None},
#        {'id': '4591155d-824c-434a-a0c8-70e3a366fcde',
#         'name': 'ethics',
#         'color': 'default',
#         'description': None},
#        {'id': 'c200ca1a-9f48-4550-8fbf-ff3fba7881c5',
#         'name': 'Agents',
#         'color': 'default',
#         'description': None},
#        {'id': 'c1643859-811b-42d9-bdd1-d476d075672b',
#         'name': 'open source',
#         'color': 'default',
#         'description': None},
#        {'id': '5cc64858-9020-4232-b8e6-206dd2167634',
#         'name': 'RAG',
#         'color': 'default',
#         'description': None},
#        {'id': 'fa787575-2d38-48c6-84ae-d83b3866727e',
#         'name': 'alignment',
#         'color': 'default',
#         'description': None},
#        {'id': 'ede47e60-3a45-4152-a52b-5b160464232f',
#         'name': 'Evals',
#         'color': 'default',
#         'description': None},
#        {'id': 'bc6d856d-ce4b-47e5-9a93-d6710df61775',
#         'name': 'Data4Good',
#         'color': 'default',
#         'description': None}]}},
#     'Level': {'id': 'u_%5El',
#      'name': 'Level',
#      'type': 'select',
#      'select': {'options': [{'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#         'name': '🤓',
#         'color': 'red',
#         'description': None},
#        {'id': '24a6a96f-bf3d-4def-afed-d14be4ea6ecd',
#         'name': '🤓 🤓',
#         'color': 'default',
#         'description': None},
#        {'id': '803fac75-9bdb-4b53-894e-1edf15f0fb39',
#         'name': '🤓 🤓 🤓',
#         'color': 'purple',
#         'description': None}]}},
#     'Status': {'id': 'wV%3A%7B',
#      'name': 'Status',
#      'type': 'status',
#      'status': {'options': [{'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#         'name': 'Unfiled',
#         'color': 'default',
#         'description': None},
#        {'id': '4f964979-5cb1-44d9-af72-7f8896fe3c25',
#         'name': 'In progress',
#         'color': 'blue',
#         'description': None},
#        {'id': '89ae0dd1-4ee8-4ac0-9273-dc8c9cec1dee',
#         'name': 'Filed',
#         'color': 'green',
#         'description': None}],
#       'groups': [{'id': 'f27c67c9-f3bc-47f7-a526-8534e951e71a',
#         'name': 'To-do',
#         'color': 'gray',
#         'option_ids': ['1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df']},
#        {'id': '79bf8880-5d2c-493c-8aae-46ce684b22a5',
#         'name': 'In progress',
#         'color': 'blue',
#         'option_ids': ['4f964979-5cb1-44d9-af72-7f8896fe3c25']},
#        {'id': 'db06c4f1-c99b-4ec6-954a-c91b93c227f9',
#         'name': 'Complete',
#         'color': 'green',
#         'option_ids': ['89ae0dd1-4ee8-4ac0-9273-dc8c9cec1dee']}]}},
#     'Date added': {'id': 'xmb%3D',
#      'name': 'Date added',
#      'type': 'created_time',
#      'created_time': {}},
#     'Name': {'id': 'title', 'name': 'Name', 'type': 'title', 'title': {}}},
#    'parent': {'type': 'workspace', 'workspace': True},
#    'url': 'https://www.notion.so/cc7af67e48be438785141ded52f9bd6b',
#    'public_url': None,
#    'archived': False,
#    'in_trash': False},
#   {'object': 'database',
#    'id': '4d42edb4-5cda-4f60-a50b-ea01eb0eb8ce',
#    'cover': None,
#    'icon': None,
#    'created_time': '2023-02-14T22:09:00.000Z',
#    'created_by': {'object': 'user',
#     'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92'},
#    'last_edited_by': {'object': 'user',
#     'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92'},
#    'last_edited_time': '2023-02-14T22:09:00.000Z',
#    'title': [],
#    'description': [],
#    'is_inline': True,
#    'properties': {'en': {'id': '%40jPi',
#      'name': 'en',
#      'type': 'rich_text',
#      'rich_text': {}},
#     'Files': {'id': 'DAFM', 'name': 'Files', 'type': 'files', 'files': {}},
#     'it': {'id': 'E%3BaK', 'name': 'it', 'type': 'rich_text', 'rich_text': {}},
#     'nl': {'id': 'G_VY', 'name': 'nl', 'type': 'rich_text', 'rich_text': {}},
#     'pl': {'id': 'HXZN', 'name': 'pl', 'type': 'rich_text', 'rich_text': {}},
#     'ru': {'id': 'Xck%60', 'name': 'ru', 'type': 'rich_text', 'rich_text': {}},
#     'fr': {'id': 'vKUK', 'name': 'fr', 'type': 'rich_text', 'rich_text': {}},
#     'es': {'id': 'yri%7D', 'name': 'es', 'type': 'rich_text', 'rich_text': {}},
#     'de': {'id': 'zbj%3D', 'name': 'de', 'type': 'rich_text', 'rich_text': {}},
#     'Function': {'id': 'title',
#      'name': 'Function',
#      'type': 'title',
#      'title': {}}},
#    'parent': {'type': 'page_id',
#     'page_id': 'f11202b8-194c-4462-ba62-c137855fec60'},
#    'url': 'https://www.notion.so/4d42edb45cda4f60a50bea01eb0eb8ce',
#    'public_url': None,
#    'archived': False,
#    'in_trash': False}],
#  'next_cursor': None,
#  'has_more': False,
#  'type': 'page_or_database',
#  'page_or_database': {},
#  'request_id': '39cc2fd1-8495-4a0a-b747-8353673bf006'}

# %% [markdown]
# Now we can get all the pages from each database.

# %%
# Function to query pages in a database
def query_database(database_id):
    response = notion.databases.query(database_id=database_id)
    return response

# Initialize an empty list to collect the page dictionaries
pages_db = []

# Loop over each database ID and query its pages
for database_id in database_ids:
    
    # Query the database for pages (assuming it returns a list of dicts)
    pages = query_database(database_id)
    
    # Append the pages (dicts) from the current database to all_pages list
    pages_db.extend(pages["results"])

print(f"Total pages: {len(pages_db)}")
pprint(pages_db)
# Out:
# Total pages: 102
# [{'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-04-02T07:39:00.000Z',
#   'icon': None,
#   'id': '6731349e-a37b-4a75-b100-66facfb2ea09',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-04-02T07:39:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-04-02T07:39:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'purple',
#                                       'id': '803fac75-9bdb-4b53-894e-1edf15f0fb39',
#                                       'name': '🤓 🤓 🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'A Humanitarian Crises '
#                                                    'Situation Report AI '
#                                                    'Assistant: Exploring '
#                                                    'LLMOps with Prompt Flow',
#                                      'text': {'content': 'A Humanitarian '
#                                                          'Crises Situation '
#                                                          'Report AI Assistant: '
#                                                          'Exploring LLMOps '
#                                                          'with Prompt Flow',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': '53fc6407-3a91-4070-be31-5067d85f4bb5',
#                                             'name': 'MLOps'},
#                                            {'color': 'default',
#                                             'id': 'f003ee9b-8a8b-4b5f-8717-b5b015b083bc',
#                                             'name': 'LLMs'},
#                                            {'color': 'default',
#                                             'id': 'ede47e60-3a45-4152-a52b-5b160464232f',
#                                             'name': 'Evals'},
#                                            {'color': 'default',
#                                             'id': 'bc6d856d-ce4b-47e5-9a93-d6710df61775',
#                                             'name': 'Data4Good'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://towardsdatascience.com/a-humanitarian-crises-situation-report-ai-assistant-exploring-llmops-with-prompt-flow-32968b7a878b'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/A-Humanitarian-Crises-Situation-Report-AI-Assistant-Exploring-LLMOps-with-Prompt-Flow-6731349ea37b4a75b10066facfb2ea09'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-03-25T10:47:00.000Z',
#   'icon': None,
#   'id': 'fa5e026d-201d-43b1-9a63-1f469ee02d21',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-03-25T10:47:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-03-25T10:47:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Exploring AI, tech trends, '
#                                                    'and engineering in a '
#                                                    'uniquely engaging blog for '
#                                                    'the curious mind.',
#                                      'text': {'content': 'Exploring AI, tech '
#                                                          'trends, and '
#                                                          'engineering in a '
#                                                          'uniquely engaging '
#                                                          'blog for the curious '
#                                                          'mind.',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'red',
#                                             'id': '5a50af15-2d86-490b-8cf6-22fadf4e7982',
#                                             'name': 'learning'},
#                                            {'color': 'default',
#                                             'id': 'f740529c-bc2b-4143-8b19-cc8d0fa28809',
#                                             'name': 'blog'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://jeremylondon.com/'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Exploring-AI-tech-trends-and-engineering-in-a-uniquely-engaging-blog-for-the-curious-mind-fa5e026d201d43b19a631f469ee02d21'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-03-21T09:46:00.000Z',
#   'icon': None,
#   'id': 'cd0a5cfa-bbe7-4479-86b3-7d5fe0e958a2',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-03-21T09:46:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-03-21T09:46:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Using LLM-as-a-judge '
#                                                    '🧑\u200d⚖️ for an automated '
#                                                    'and versatile evaluation - '
#                                                    'Hugging Face Open-Source '
#                                                    'AI Cookbook',
#                                      'text': {'content': 'Using LLM-as-a-judge '
#                                                          '🧑\u200d⚖️ for an '
#                                                          'automated and '
#                                                          'versatile evaluation '
#                                                          '- Hugging Face '
#                                                          'Open-Source AI '
#                                                          'Cookbook',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'gray',
#                                             'id': '002ff61b-787d-4c14-a8e2-f30c73f2f677',
#                                             'name': 'code'},
#                                            {'color': 'blue',
#                                             'id': 'd140b1c5-d3ce-43f9-af55-a302a2cbe31d',
#                                             'name': 'tutorial'},
#                                            {'color': 'default',
#                                             'id': 'f003ee9b-8a8b-4b5f-8717-b5b015b083bc',
#                                             'name': 'LLMs'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://huggingface.co/learn/cookbook/llm_judge'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Using-LLM-as-a-judge-for-an-automated-and-versatile-evaluation-Hugging-Face-Open-Source-AI-C-cd0a5cfabbe7447986b37d5fe0e958a2'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-02-22T15:27:00.000Z',
#   'icon': None,
#   'id': '379455ef-0a75-4521-9f99-defc5284376e',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-02-22T15:27:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-02-22T15:27:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Introduction to '
#                                                    'Data-Centric AI',
#                                      'text': {'content': 'Introduction to '
#                                                          'Data-Centric AI',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'red',
#                                             'id': '5a50af15-2d86-490b-8cf6-22fadf4e7982',
#                                             'name': 'learning'},
#                                            {'color': 'default',
#                                             'id': '147a4acc-7510-4b66-8a99-44f59271c1ae',
#                                             'name': 'course'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://dcai.csail.mit.edu/'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Introduction-to-Data-Centric-AI-379455ef0a7545219f99defc5284376e'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-02-22T15:17:00.000Z',
#   'icon': None,
#   'id': '4b2bcca2-9a83-4cac-838d-85140296b58a',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-02-22T15:17:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-02-22T15:17:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'labmlai/annotated_deep_learning_paper_implementations: '
#                                                    '🧑\u200d🏫 60 '
#                                                    'Implementations/tutorials '
#                                                    'of deep learning papers '
#                                                    'with side-by-side notes 📝; '
#                                                    'including transformers '
#                                                    '(original, xl, switch, '
#                                                    'feedback, vit, ...), '
#                                                    'optimizers (adam, '
#                                                    'adabelief, sophia, ...), '
#                                                    'gans(cyclegan, stylegan2, '
#                                                    '...), 🎮 reinforcement '
#                                                    'learning (ppo, dqn), '
#                                                    'capsnet, distillation, ... '
#                                                    '🧠',
#                                      'text': {'content': 'labmlai/annotated_deep_learning_paper_implementations: '
#                                                          '🧑\u200d🏫 60 '
#                                                          'Implementations/tutorials '
#                                                          'of deep learning '
#                                                          'papers with '
#                                                          'side-by-side notes '
#                                                          '📝; including '
#                                                          'transformers '
#                                                          '(original, xl, '
#                                                          'switch, feedback, '
#                                                          'vit, ...), '
#                                                          'optimizers (adam, '
#                                                          'adabelief, sophia, '
#                                                          '...), gans(cyclegan, '
#                                                          'stylegan2, ...), 🎮 '
#                                                          'reinforcement '
#                                                          'learning (ppo, dqn), '
#                                                          'capsnet, '
#                                                          'distillation, ... 🧠',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'blue',
#                                             'id': 'd140b1c5-d3ce-43f9-af55-a302a2cbe31d',
#                                             'name': 'tutorial'},
#                                            {'color': 'red',
#                                             'id': '5a50af15-2d86-490b-8cf6-22fadf4e7982',
#                                             'name': 'learning'},
#                                            {'color': 'yellow',
#                                             'id': 'e8e0c835-107a-49bb-8a16-3a7301822cdc',
#                                             'name': 'transformers'},
#                                            {'color': 'default',
#                                             'id': 'cc2c7544-a96f-4cf3-bb6f-6565ff5a0720',
#                                             'name': 'deep learning'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://github.com/labmlai/annotated_deep_learning_paper_implementations'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/labmlai-annotated_deep_learning_paper_implementations-60-Implementations-tutorials-of-deep-le-4b2bcca29a834cac838d85140296b58a'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-02-22T15:14:00.000Z',
#   'icon': None,
#   'id': 'd5d12f12-8e9b-421c-9ec1-fc1a8c1d596a',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-02-22T15:14:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-02-22T15:14:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Disrupting malicious uses '
#                                                    'of AI by state-affiliated '
#                                                    'threat actors',
#                                      'text': {'content': 'Disrupting malicious '
#                                                          'uses of AI by '
#                                                          'state-affiliated '
#                                                          'threat actors',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': '4591155d-824c-434a-a0c8-70e3a366fcde',
#                                             'name': 'ethics'},
#                                            {'color': 'default',
#                                             'id': 'fa787575-2d38-48c6-84ae-d83b3866727e',
#                                             'name': 'alignment'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://openai.com/blog/disrupting-malicious-uses-of-ai-by-state-affiliated-threat-actors'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Disrupting-malicious-uses-of-AI-by-state-affiliated-threat-actors-d5d12f128e9b421c9ec1fc1a8c1d596a'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-02-22T15:13:00.000Z',
#   'icon': None,
#   'id': '56b7426c-9031-4d3e-808a-f9d54987c415',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-02-22T15:13:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-02-22T15:13:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Do you actually need a '
#                                                    'vector database? | Ethan '
#                                                    'Rosenthal',
#                                      'text': {'content': 'Do you actually need '
#                                                          'a vector database? | '
#                                                          'Ethan Rosenthal',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': 'f740529c-bc2b-4143-8b19-cc8d0fa28809',
#                                             'name': 'blog'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://www.ethanrosenthal.com/2023/04/10/nn-vs-ann/?source=post_page-----fc392e48ab78--------------------------------'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Do-you-actually-need-a-vector-database-Ethan-Rosenthal-56b7426c90314d3e808af9d54987c415'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-02-05T11:25:00.000Z',
#   'icon': None,
#   'id': '82e4e930-2dcf-4703-aaf7-d3d4e6d69255',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-02-05T11:25:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-02-05T11:25:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'huggingface/alignment-handbook: '
#                                                    'Robust recipes to align '
#                                                    'language models with human '
#                                                    'and AI preferences',
#                                      'text': {'content': 'huggingface/alignment-handbook: '
#                                                          'Robust recipes to '
#                                                          'align language '
#                                                          'models with human '
#                                                          'and AI preferences',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': '91388bec-6859-4c3f-b623-0419aefed0fd',
#                                             'name': 'RLHF'},
#                                            {'color': 'default',
#                                             'id': 'fa787575-2d38-48c6-84ae-d83b3866727e',
#                                             'name': 'alignment'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://github.com/huggingface/alignment-handbook'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/huggingface-alignment-handbook-Robust-recipes-to-align-language-models-with-human-and-AI-preference-82e4e9302dcf4703aaf7d3d4e6d69255'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-01-22T09:16:00.000Z',
#   'icon': None,
#   'id': 'd26471cf-a6a4-44d6-96d6-a7db09b4db13',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-01-22T09:16:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-01-22T09:16:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'default',
#                                       'id': '24a6a96f-bf3d-4def-afed-d14be4ea6ecd',
#                                       'name': '🤓 🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'hackerllama - Sentence '
#                                                    'Embeddings. Introduction '
#                                                    'to Sentence Embeddings',
#                                      'text': {'content': 'hackerllama - '
#                                                          'Sentence Embeddings. '
#                                                          'Introduction to '
#                                                          'Sentence Embeddings',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'red',
#                                             'id': '5a50af15-2d86-490b-8cf6-22fadf4e7982',
#                                             'name': 'learning'},
#                                            {'color': 'default',
#                                             'id': 'f003ee9b-8a8b-4b5f-8717-b5b015b083bc',
#                                             'name': 'LLMs'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://osanseviero.github.io/hackerllama/blog/posts/sentence_embeddings/'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/hackerllama-Sentence-Embeddings-Introduction-to-Sentence-Embeddings-d26471cfa6a444d696d6a7db09b4db13'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-01-22T09:15:00.000Z',
#   'icon': None,
#   'id': '098666ee-498e-45f6-837a-b5a2c4b04893',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-01-22T09:15:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-01-22T09:15:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'default',
#                                       'id': '24a6a96f-bf3d-4def-afed-d14be4ea6ecd',
#                                       'name': '🤓 🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Weird properties of large '
#                                                    'language models',
#                                      'text': {'content': 'Weird properties of '
#                                                          'large language '
#                                                          'models',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': 'f003ee9b-8a8b-4b5f-8717-b5b015b083bc',
#                                             'name': 'LLMs'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://moreisdifferent.blog/p/weird-properties-of-large-language'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Weird-properties-of-large-language-models-098666ee498e45f6837ab5a2c4b04893'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-01-22T09:09:00.000Z',
#   'icon': None,
#   'id': '5357961b-4651-41ba-a06e-3ad7118e6612',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-01-22T09:09:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-01-22T09:09:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'default',
#                                       'id': '24a6a96f-bf3d-4def-afed-d14be4ea6ecd',
#                                       'name': '🤓 🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Python Developer Tooling '
#                                                    'Handbook',
#                                      'text': {'content': 'Python Developer '
#                                                          'Tooling Handbook',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'brown',
#                                             'id': 'f6f26d21-6434-41dc-a92b-8a59b85476d3',
#                                             'name': 'software engineering'},
#                                            {'color': 'default',
#                                             'id': 'c1643859-811b-42d9-bdd1-d476d075672b',
#                                             'name': 'open source'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://github.com/python-developer-tooling-handbook'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Python-Developer-Tooling-Handbook-5357961b465141baa06e3ad7118e6612'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-01-17T13:55:00.000Z',
#   'icon': None,
#   'id': '2b0118f0-e9c0-4a0d-ac22-049c311c3816',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-01-17T13:55:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-01-17T13:55:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Google DeepMind’s new '
#                                                    'Gemini model looks '
#                                                    'amazing—but could signal '
#                                                    'peak AI hype',
#                                      'text': {'content': 'Google DeepMind’s '
#                                                          'new Gemini model '
#                                                          'looks amazing—but '
#                                                          'could signal peak AI '
#                                                          'hype',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': '925d193a-f7dd-4703-bb6a-d39e11fbf612',
#                                             'name': 'collaborations'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://www.technologyreview.com/2023/12/06/1084471/google-deepminds-new-gemini-model-looks-amazing-but-could-signal-peak-ai-hype/'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Google-DeepMind-s-new-Gemini-model-looks-amazing-but-could-signal-peak-AI-hype-2b0118f0e9c04a0dac22049c311c3816'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-01-16T12:26:00.000Z',
#   'icon': None,
#   'id': 'dddc91f8-8795-4081-85cd-5a1ae05a7a3e',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-01-16T12:26:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-01-16T12:26:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'purple',
#                                       'id': '803fac75-9bdb-4b53-894e-1edf15f0fb39',
#                                       'name': '🤓 🤓 🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Transformers From Scratch',
#                                      'text': {'content': 'Transformers From '
#                                                          'Scratch',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'red',
#                                             'id': '5a50af15-2d86-490b-8cf6-22fadf4e7982',
#                                             'name': 'learning'},
#                                            {'color': 'yellow',
#                                             'id': 'e8e0c835-107a-49bb-8a16-3a7301822cdc',
#                                             'name': 'transformers'},
#                                            {'color': 'default',
#                                             'id': 'f740529c-bc2b-4143-8b19-cc8d0fa28809',
#                                             'name': 'blog'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://blog.matdmiller.com/posts/2023-06-10_transformers/notebook.html?utm_source=tldrai'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Transformers-From-Scratch-dddc91f88795408185cd5a1ae05a7a3e'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2024-01-16T12:25:00.000Z',
#   'icon': None,
#   'id': '0be2673e-f466-402a-bb32-885d6c1a88db',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2024-01-16T12:25:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2024-01-16T12:25:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'default',
#                                       'id': '24a6a96f-bf3d-4def-afed-d14be4ea6ecd',
# ...
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Finding Waldo - Tech & '
#                                                    'Business',
#                                      'text': {'content': 'Finding Waldo - Tech '
#                                                          '& Business',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': '925d193a-f7dd-4703-bb6a-d39e11fbf612',
#                                             'name': 'collaborations'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://www.findingwaldo.co/'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Finding-Waldo-Tech-Business-329b28c5b61d48c89c1177abd6e1395e'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2023-06-14T16:42:00.000Z',
#   'icon': None,
#   'id': '67472c32-2058-4f57-b62e-40e2016004c9',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2023-06-14T16:42:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2023-06-14T16:42:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Exploding Topics - '
#                                                    'Discover the hottest new '
#                                                    'trends.',
#                                      'text': {'content': 'Exploding Topics - '
#                                                          'Discover the hottest '
#                                                          'new trends.',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': '925d193a-f7dd-4703-bb6a-d39e11fbf612',
#                                             'name': 'collaborations'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://explodingtopics.com/'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Exploding-Topics-Discover-the-hottest-new-trends-67472c3220584f57b62e40e2016004c9'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2023-06-14T16:38:00.000Z',
#   'icon': None,
#   'id': 'a1f45ddb-d471-407d-a201-1ae7936a2144',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2023-06-14T16:38:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2023-06-14T16:38:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'purple',
#                                       'id': '803fac75-9bdb-4b53-894e-1edf15f0fb39',
#                                       'name': '🤓 🤓 🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'vector-search-class-notes/class_notes '
#                                                    'at main · '
#                                                    'edoliberty/vector-search-class-notes',
#                                      'text': {'content': 'vector-search-class-notes/class_notes '
#                                                          'at main · '
#                                                          'edoliberty/vector-search-class-notes',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': 'f003ee9b-8a8b-4b5f-8717-b5b015b083bc',
#                                             'name': 'LLMs'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://github.com/edoliberty/vector-search-class-notes'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/vector-search-class-notes-class_notes-at-main-edoliberty-vector-search-class-notes-a1f45ddbd471407da2011ae7936a2144'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2023-04-20T08:26:00.000Z',
#   'icon': None,
#   'id': '6d68f175-3f21-42fc-b860-7378a67fdaa9',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2023-04-20T08:26:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#              'type': 'database_id'},
#   'properties': {'Date added': {'created_time': '2023-04-20T08:26:00.000Z',
#                                 'id': 'xmb%3D',
#                                 'type': 'created_time'},
#                  'Level': {'id': 'u_%5El',
#                            'select': {'color': 'red',
#                                       'id': '6232b25e-67bc-4923-9406-ae432d125d86',
#                                       'name': '🤓'},
#                            'type': 'select'},
#                  'Name': {'id': 'title',
#                           'title': [{'annotations': {'bold': False,
#                                                      'code': False,
#                                                      'color': 'default',
#                                                      'italic': False,
#                                                      'strikethrough': False,
#                                                      'underline': False},
#                                      'href': None,
#                                      'plain_text': 'Kadoa | AI Web Scraper',
#                                      'text': {'content': 'Kadoa | AI Web '
#                                                          'Scraper',
#                                               'link': None},
#                                      'type': 'text'}],
#                           'type': 'title'},
#                  'Status': {'id': 'wV%3A%7B',
#                             'status': {'color': 'default',
#                                        'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                        'name': 'Unfiled'},
#                             'type': 'status'},
#                  'Tags': {'id': 'lo%3Cz',
#                           'multi_select': [{'color': 'default',
#                                             'id': '85f28320-bf3d-44df-a92c-ec3a3cd214c5',
#                                             'name': 'tools'}],
#                           'type': 'multi_select'},
#                  'URL': {'id': 'IlqV',
#                          'type': 'url',
#                          'url': 'https://www.kadoa.com/'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/Kadoa-AI-Web-Scraper-6d68f1753f2142fcb8607378a67fdaa9'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2023-02-14T22:09:00.000Z',
#   'icon': None,
#   'id': '292b2b86-df1c-4477-9ac1-0b960deeeff2',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2023-02-14T22:09:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': '4d42edb4-5cda-4f60-a50b-ea01eb0eb8ce',
#              'type': 'database_id'},
#   'properties': {'Files': {'files': [{'file': {'expiry_time': '2024-09-24T12:11:02.167Z',
#                                                'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/eee109b4-93ec-42f5-884c-bdf616b04771/8f0c3868-10a3-4989-a3b9-f2006821bd4b/2714.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240924%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240924T111102Z&X-Amz-Expires=3600&X-Amz-Signature=44ff01b25a82fcc6c3625f48e4989573accdad8a5c2a5226b33f6eba9b7de489&X-Amz-SignedHeaders=host&x-id=GetObject'},
#                                       'name': 'https://github.githubassets.com/images/icons/emoji/unicode/2714.png',
#                                       'type': 'file'}],
#                            'id': 'DAFM',
#                            'type': 'files'},
#                  'Function': {'id': 'title',
#                               'title': [{'annotations': {'bold': False,
#                                                          'code': False,
#                                                          'color': 'default',
#                                                          'italic': False,
#                                                          'strikethrough': False,
#                                                          'underline': False},
#                                          'href': None,
#                                          'plain_text': 'flesch_reading_ease',
#                                          'text': {'content': 'flesch_reading_ease',
#                                                   'link': None},
#                                          'type': 'text'}],
#                               'type': 'title'},
#                  'de': {'id': 'zbj%3D', 'rich_text': [], 'type': 'rich_text'},
#                  'en': {'id': '%40jPi', 'rich_text': [], 'type': 'rich_text'},
#                  'es': {'id': 'yri%7D', 'rich_text': [], 'type': 'rich_text'},
#                  'fr': {'id': 'vKUK', 'rich_text': [], 'type': 'rich_text'},
#                  'it': {'id': 'E%3BaK', 'rich_text': [], 'type': 'rich_text'},
#                  'nl': {'id': 'G_VY', 'rich_text': [], 'type': 'rich_text'},
#                  'pl': {'id': 'HXZN', 'rich_text': [], 'type': 'rich_text'},
#                  'ru': {'id': 'Xck%60', 'rich_text': [], 'type': 'rich_text'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/flesch_reading_ease-292b2b86df1c44779ac10b960deeeff2'},
#  {'archived': False,
#   'cover': None,
#   'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                  'object': 'user'},
#   'created_time': '2023-02-14T22:09:00.000Z',
#   'icon': None,
#   'id': 'f47cbd29-7e46-41b1-aa2e-8c139e4983d8',
#   'in_trash': False,
#   'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                      'object': 'user'},
#   'last_edited_time': '2023-02-14T22:09:00.000Z',
#   'object': 'page',
#   'parent': {'database_id': '4d42edb4-5cda-4f60-a50b-ea01eb0eb8ce',
#              'type': 'database_id'},
#   'properties': {'Files': {'files': [], 'id': 'DAFM', 'type': 'files'},
#                  'Function': {'id': 'title',
#                               'title': [{'annotations': {'bold': False,
#                                                          'code': False,
#                                                          'color': 'default',
#                                                          'italic': False,
#                                                          'strikethrough': False,
#                                                          'underline': False},
#                                          'href': None,
#                                          'plain_text': 'gunning_fog',
#                                          'text': {'content': 'gunning_fog',
#                                                   'link': None},
#                                          'type': 'text'}],
#                               'type': 'title'},
#                  'de': {'id': 'zbj%3D', 'rich_text': [], 'type': 'rich_text'},
#                  'en': {'id': '%40jPi', 'rich_text': [], 'type': 'rich_text'},
#                  'es': {'id': 'yri%7D', 'rich_text': [], 'type': 'rich_text'},
#                  'fr': {'id': 'vKUK', 'rich_text': [], 'type': 'rich_text'},
#                  'it': {'id': 'E%3BaK', 'rich_text': [], 'type': 'rich_text'},
#                  'nl': {'id': 'G_VY', 'rich_text': [], 'type': 'rich_text'},
#                  'pl': {'id': 'HXZN', 'rich_text': [], 'type': 'rich_text'},
#                  'ru': {'id': 'Xck%60', 'rich_text': [], 'type': 'rich_text'}},
#   'public_url': None,
#   'url': 'https://www.notion.so/gunning_fog-f47cbd297e4641b1aa2e8c139e4983d8'}]

# %% [markdown]
# This is great! But the output of each database will vary dramatically. This pages in this database simply have the name of a web page, its URL, and some tags.
#
# The question is, how do we extract content from databases that have different structures?
#
# We could start out by taking all the properties for each page.

# %%
def extract_properties(pages):
    # Initialize an empty list to store all properties
    all_properties = []

    # Loop through each page and extract its properties
    for page in pages:
        properties = page.get('properties', {})
        all_properties.append(properties)

    print(f"Extracted properties from {len(all_properties)} pages")
    return all_properties

properties_db = extract_properties(pages_db)
pprint(pages_db[0])  # Print the first page's properties as an example
# Out:
# Extracted properties from 102 pages
# {'archived': False,
#  'cover': None,
#  'created_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92', 'object': 'user'},
#  'created_time': '2024-04-02T07:39:00.000Z',
#  'icon': None,
#  'id': '6731349e-a37b-4a75-b100-66facfb2ea09',
#  'in_trash': False,
#  'last_edited_by': {'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92',
#                     'object': 'user'},
#  'last_edited_time': '2024-04-02T07:39:00.000Z',
#  'object': 'page',
#  'parent': {'database_id': 'cc7af67e-48be-4387-8514-1ded52f9bd6b',
#             'type': 'database_id'},
#  'properties': {'Date added': {'created_time': '2024-04-02T07:39:00.000Z',
#                                'id': 'xmb%3D',
#                                'type': 'created_time'},
#                 'Level': {'id': 'u_%5El',
#                           'select': {'color': 'purple',
#                                      'id': '803fac75-9bdb-4b53-894e-1edf15f0fb39',
#                                      'name': '🤓 🤓 🤓'},
#                           'type': 'select'},
#                 'Name': {'id': 'title',
#                          'title': [{'annotations': {'bold': False,
#                                                     'code': False,
#                                                     'color': 'default',
#                                                     'italic': False,
#                                                     'strikethrough': False,
#                                                     'underline': False},
#                                     'href': None,
#                                     'plain_text': 'A Humanitarian Crises '
#                                                   'Situation Report AI '
#                                                   'Assistant: Exploring LLMOps '
#                                                   'with Prompt Flow',
#                                     'text': {'content': 'A Humanitarian Crises '
#                                                         'Situation Report AI '
#                                                         'Assistant: Exploring '
#                                                         'LLMOps with Prompt '
#                                                         'Flow',
#                                              'link': None},
#                                     'type': 'text'}],
#                          'type': 'title'},
#                 'Status': {'id': 'wV%3A%7B',
#                            'status': {'color': 'default',
#                                       'id': '1546523c-4fef-4fc0-a4bb-f4ec5ca6f2df',
#                                       'name': 'Unfiled'},
#                            'type': 'status'},
#                 'Tags': {'id': 'lo%3Cz',
#                          'multi_select': [{'color': 'default',
#                                            'id': '53fc6407-3a91-4070-be31-5067d85f4bb5',
#                                            'name': 'MLOps'},
#                                           {'color': 'default',
#                                            'id': 'f003ee9b-8a8b-4b5f-8717-b5b015b083bc',
#                                            'name': 'LLMs'},
#                                           {'color': 'default',
#                                            'id': 'ede47e60-3a45-4152-a52b-5b160464232f',
#                                            'name': 'Evals'},
#                                           {'color': 'default',
#                                            'id': 'bc6d856d-ce4b-47e5-9a93-d6710df61775',
#                                            'name': 'Data4Good'}],
#                          'type': 'multi_select'},
#                 'URL': {'id': 'IlqV',
#                         'type': 'url',
#                         'url': 'https://towardsdatascience.com/a-humanitarian-crises-situation-report-ai-assistant-exploring-llmops-with-prompt-flow-32968b7a878b'}},
#  'public_url': None,
#  'url': 'https://www.notion.so/A-Humanitarian-Crises-Situation-Report-AI-Assistant-Exploring-LLMOps-with-Prompt-Flow-6731349ea37b4a75b10066facfb2ea09'}

# %% [markdown]
# This is great! But only two of my many pages in Notion are databases. The rest are pages with content.
# So how do we access the content of these pages? The code below only retrieves pages from a given database (with database id).

# %%
# Function to search for pages not in a database
def get_non_database_pages():
    response = notion.search(
        filter={
            "value": "page",  # Search for pages
            "property": "object"
        }
    )
    non_database_pages = []

    # Filter out pages that are not part of a database
    for page in response['results']:
        if page['parent']['type'] != 'database_id':  # Ensure it's not in a database
            non_database_pages.append(page)

    return non_database_pages

# Get the non-database pages
pages = get_non_database_pages()

# Extract properties from non-database pages
properties_pages = extract_properties(pages)

# Print the first page's properties as an example
pprint(properties_pages)
# Out:
# Extracted properties from 13 pages
# [{'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Interviews',
#                        'text': {'content': 'Interviews', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Microsoft Create',
#                        'text': {'content': 'Microsoft Create', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'CFPs',
#                        'text': {'content': 'CFPs', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Wilkommen in Berlin',
#                        'text': {'content': 'Wilkommen in Berlin', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title', 'title': [], 'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Weaviate',
#                        'text': {'content': 'Weaviate', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Grammarly',
#                        'text': {'content': 'Grammarly', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Machine Learning Week Europe',
#                        'text': {'content': 'Machine Learning Week Europe',
#                                 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Qdrant',
#                        'text': {'content': 'Qdrant', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': '5 tips for safe use of AI',
#                        'text': {'content': '5 tips for safe use of AI',
#                                 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': True,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Leveraging AI tools to enhance everyday '
#                                      'productivity',
#                        'text': {'content': 'Leveraging AI tools to enhance '
#                                            'everyday productivity',
#                                 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Climatiq',
#                        'text': {'content': 'Climatiq', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}},
#  {'title': {'id': 'title',
#             'title': [{'annotations': {'bold': False,
#                                        'code': False,
#                                        'color': 'default',
#                                        'italic': False,
#                                        'strikethrough': False,
#                                        'underline': False},
#                        'href': None,
#                        'plain_text': 'Aleph Alpha',
#                        'text': {'content': 'Aleph Alpha', 'link': None},
#                        'type': 'text'}],
#             'type': 'title'}}]

# %% [markdown]
# This code gives us the properties for each page (that's not part of a database). However, it doesn't give us the content of the page.

# %% [markdown]
# So now we need to get the content of each page by returning the blocks of the page.

# %%
# Function to get all blocks for a given page ID
def get_page_blocks(page_id):
    # Retrieve blocks on the page
    blocks = notion.blocks.children.list(block_id=page_id)
    return blocks['results']

page_blocks = []
# Loop over each page and get its blocks
for page in pages:
    # Get all blocks on the page
    blocks = get_page_blocks(page['id'])
    # Append blocks to the list
    page_blocks.extend(blocks)

# %% [markdown]
# We can do this and that's great. But parsing the blocks to extract the plain text sucks...
#
# Maybe we have to specify all the different "types" that we want to extract plain text from?

# %%
page_blocks[0]
# Out:
# {'object': 'block',
#  'id': 'd8e4bad2-19b6-4097-b2ca-e157b4137f1f',
#  'parent': {'type': 'page_id',
#   'page_id': 'f28b0596-f23f-4591-a958-b39db557bd7a'},
#  'created_time': '2023-12-21T21:36:00.000Z',
#  'last_edited_time': '2023-12-21T21:57:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92'},
#  'last_edited_by': {'object': 'user',
#   'id': '2d38b5ac-c257-418c-bbf1-b13265b09e92'},
#  'has_children': True,
#  'archived': False,
#  'in_trash': False,
#  'type': 'child_page',
#  'child_page': {'title': 'Climatiq'}}

# %%
# Function to get plain text from a rich text array
def get_plain_text_from_rich_text(rich_text):
    return "".join([t['plain_text'] for t in rich_text])

# Function to get plain text from different block types
def get_text_from_block(block):
    text = ""

    # Check if the block supports rich_text
    if 'rich_text' in block[block['type']]:
        text = get_plain_text_from_rich_text(block[block['type']]['rich_text'])
    else:
        # Handle non-rich-text block types
        block_type = block['type']
        if block_type == 'unsupported':
            text = "[Unsupported block type]"
        elif block_type == 'bookmark':
            text = block['bookmark']['url']
        elif block_type == 'child_database':
            text = block['child_database']['title']
        elif block_type == 'child_page':
            text = block['child_page']['title']
        # elif block_type in ['embed', 'video', 'file', 'image', 'pdf']:
        #     text = get_media_source_text(block)
        elif block_type == 'equation':
            text = block['equation']['expression']
        elif block_type == 'link_preview':
            text = block['link_preview']['url']
        elif block_type == 'synced_block':
            text = f"Synced with block ID: {block['synced_block'].get('synced_from', {}).get('block_id', 'Unknown')}"
        elif block_type == 'table':
            text = f"Table width: {block['table']['table_width']}"
        elif block_type == 'table_of_contents':
            text = f"ToC color: {block['table_of_contents']['color']}"
        elif block_type in ['breadcrumb', 'column_list', 'divider']:
            text = "No text available"
        else:
            text = "[Needs case added]"

    # Check if block has children
    if block['has_children']:
        text += " (Has children)"

# %%
output = [get_text_from_block(block) for block in page_blocks]
pprint(output)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
    return f"{block['type']}: {text}"

# Function to retrieve block children (first-level)
async def retrieve_block_children(notion, block_id):
    print("Retrieving blocks (async)...")
    blocks = []

    # Iterate through all first-level blocks on the page
    async for block in iterate_paginated_api(notion.blocks.children.list, block_id=block_id):
        blocks.append(block)

    return blocks

# Function to print text from all blocks
def print_block_text(blocks):
    print("Displaying blocks:")
    for block in blocks:
        text = get_text_from_block(block)
        print(text)

# Main function
async def main():
    # Retrieve all block children from the page
    blocks = await retrieve_block_children(notion, page_id)
    # Print plain text for each block
    print_block_text(blocks)

# Run the main function
import asyncio
asyncio.run(main())
